# %% [markdown]
# <a href="https://colab.research.google.com/github/thotasriharsha/ReinforcementLearning/blob/main/RL_ASS(1)_2159.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Greedy Multi-Armed Bandit
# Arithmetic Mean Method

n = int(input("Enter number of machines: "))

machines = {}

for i in range(n):
    name = input(f"\nEnter name of machine {i + 1}: ")
    rewards = list(map(float, input("Enter observed rewards separated by spaces: ").split()))

    machines[name] = rewards

print("\n--- Estimated Q(a) Values ---")

q_values = {}

for name, rewards in machines.items():
    q = sum(rewards) / len(rewards)
    q_values[name] = q

    print(f"Machine {name}")
    print(f"Rewards: {rewards}")
    print(f"Q({name}) = {q:.2f}")

selected_machine = max(q_values, key=q_values.get)

print(f"\nGreedy Selected Machine: {selected_machine}")
# Out:
# Enter number of machines: 3
#
# Enter name of machine 1: A
# Enter observed rewards separated by spaces: 3 2 4
#
# Enter name of machine 2: B
# Enter observed rewards separated by spaces: 6 7
#
# Enter name of machine 3: C
# Enter observed rewards separated by spaces: 5 4 6
#
# --- Estimated Q(a) Values ---
# Machine A
# Rewards: [3.0, 2.0, 4.0]
# Q(A) = 3.00
# Machine B
# Rewards: [6.0, 7.0]
# Q(B) = 6.50
# Machine C
# Rewards: [5.0, 4.0, 6.0]
# Q(C) = 5.00
#
# Greedy Selected Machine: B

# %%
# Greedy Multi-Armed Bandit
# Incremental Update Method

n = int(input("Enter number of machines: "))

machines = []
rewards = {}

# Input machines and rewards
for i in range(n):
    name = input(f"\nEnter name of machine {i + 1}: ")
    reward_list = list(map(float, input("Enter observed rewards separated by spaces: ").split()))

    machines.append(name)
    rewards[name] = reward_list

# Initialize Q and N
Q = {}
N = {}

for machine in machines:
    Q[machine] = 0
    N[machine] = 0

print("\n--- Incremental Updates ---")

# Process every reward
for machine in machines:

    print(f"\nMachine {machine}")

    for reward in rewards[machine]:

        # Increment count
        N[machine] += 1

        # Incremental update formula
        Q[machine] = Q[machine] + (reward - Q[machine]) / N[machine]

        print(
            f"Reward = {reward}, "
            f"N({machine}) = {N[machine]}, "
            f"Q({machine}) = {Q[machine]:.2f}"
        )

        # Find current greedy machine
        selected = max(Q, key=Q.get)

        print(f"Current Greedy Selection: {selected}")

print("\n--- Final Q Values ---")

for machine in machines:
    print(f"Q({machine}) = {Q[machine]:.2f}")

selected_machine = max(Q, key=Q.get)

print(f"\nGreedy Selected Machine: {selected_machine}")
# Out:
# Enter number of machines: 3
#
# Enter name of machine 1: A
# Enter observed rewards separated by spaces: 3 2 4
#
# Enter name of machine 2: B
# Enter observed rewards separated by spaces: 6 7
#
# Enter name of machine 3: C
# Enter observed rewards separated by spaces: 5 4 6
#
# --- Incremental Updates ---
#
# Machine A
# Reward = 3.0, N(A) = 1, Q(A) = 3.00
# Current Greedy Selection: A
# Reward = 2.0, N(A) = 2, Q(A) = 2.50
# Current Greedy Selection: A
# Reward = 4.0, N(A) = 3, Q(A) = 3.00
# Current Greedy Selection: A
#
# Machine B
# Reward = 6.0, N(B) = 1, Q(B) = 6.00
# Current Greedy Selection: B
# Reward = 7.0, N(B) = 2, Q(B) = 6.50
# Current Greedy Selection: B
#
# Machine C
# Reward = 5.0, N(C) = 1, Q(C) = 5.00
# Current Greedy Selection: B
# Reward = 4.0, N(C) = 2, Q(C) = 4.50
# Current Greedy Selection: B
# Reward = 6.0, N(C) = 3, Q(C) = 5.00
# Current Greedy Selection: B
#
# --- Final Q Values ---
# Q(A) = 3.00
# Q(B) = 6.50
# Q(C) = 5.00
#
# Greedy Selected Machine: B
